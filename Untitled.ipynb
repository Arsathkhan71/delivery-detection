# %%
from ultralytics import YOLO

# %%
# model = YOLO("best.pt")

# %%
#model = YOLO("best2.pt")

# %%
# model = YOLO("best.pt")
# model.fuse()

# %%
model = YOLO("best2.pt")
model.fuse()
# Out:
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs

# %%
#model.train(data="data_re.yaml", epochs=10, show=True, imgsz=640, batch=10)
# Out:
# New https://pypi.org/project/ultralytics/8.0.202 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.81  Python-3.10.11 torch-2.0.1+cpu CPU
# ...

# %%
results = model.predict(source="http://152.58.205.95", show=True, conf=0.3, save=True, line_thickness=2)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 results = model.predict(source="http://152.58.205.95", show=True, conf=0.3, save=True, line_thickness=2)
#
# File ~\yolov8cpu\lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\yolov8cpu\lib\site-packages\ultralytics\yolo\engine\model.py:252, in YOLO.predict(self, source, stream, **kwargs)
#     250 else:  # only update args if predictor is already setup
#     251     self.predictor.args = get_cfg(self.predictor.args, overrides)
# --> 252 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# ...
